# %%
from MS_sheets import * 
import MS
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Micha\Desktop\Projects\personal\PartyFinder\PartyFinder\discord\app\test.ipynb Cell 1 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Micha/Desktop/Projects/personal/PartyFinder/PartyFinder/discord/app/test.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> from MS_sheets import *
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Micha/Desktop/Projects/personal/PartyFinder/PartyFinder/discord/app/test.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import MS
#
# File c:\Users\Micha\Desktop\Projects\personal\PartyFinder\PartyFinder\discord\app\MS.py:3
#       1 #some general classes and functionality for maplestory
#       2 import pandas as pd
# ----> 3 from MS_jobs import gms_jobs_df
#       5 party_supports = ("Bishop", 'Dawn Warrior', 'Blaze Wizard', 'Chase', 'Mechanic', 'Shade', 'Kanna', 'Battle Mage')
# ...

# %%
df = access_google_sheet(google_sheet_url=google_sheets_urls['hluwill'])
# Out:
# C:\Users\Micha\AppData\Local\Temp\ipykernel_30028\836761987.py:1: DeprecationWarning: [Deprecated][in version 6.0.0]: client_factory will be replaced by gspread.http_client types
#   df = access_google_sheet(google_sheet_url=google_sheets_urls['hluwill'])

# %%
adjusted = MS.adjust_ba(df, 250)
minimum_ba = 1.3
supports, dps = MS.filter_players(adjusted, minimum_ba)
display(supports, dps)
# Out:
#              Timestamp Character Name  Level Class Type   BA Party  \
# 5  10/24/2023 11:31:13              f    245    Support  1.5
#
#    level_diff  fd_multiplier  adjusted_BA
# 5          -5           0.88         1.32
#               Timestamp Character Name  Level Class Type        BA Party  \
# 8   10/24/2023 11:30:11              i    260        DPS  1.460165
# 3   10/24/2023 11:30:34              d    255        DPS  1.700000
# 2   10/24/2023 11:30:11              c    260        DPS  1.800000
# 9   10/24/2023 11:30:34              j    255        DPS  1.813683
# 7   10/24/2023 11:29:41              h    245        DPS  2.627418
# 1   10/24/2023 11:29:41              b    245        DPS  2.700000
# 4   10/24/2023 11:30:50              e    253        DPS  2.200000
# 10  10/24/2023 11:30:50              k    253        DPS  2.362146
# 0   10/24/2023 11:29:17              a    250        DPS  2.500000
# 6   10/24/2023 11:29:17              g    250        DPS  3.407284
#
# ...

# %%
result = MS.match_players(supports, dps, minimum_ba, minimum_ba*1.25)
# Out:
# No more elligible supports left
# Total Party Damage 2.31212788664
# Total Party Damage 4.68812788664
# Total Party Damage 7.240127886640001
# Total Party Damage 9.98021690212
# Total Party Damage 2.75
# Total Party Damage 6.498012424200001
# [['f', 'i', 'd', 'c', 'j'], ['h', 'b', 'e', 'k']]

# %%
for party in result:
    print(adjusted.loc[adjusted["Character Name"].isin(party), "adjusted_BA"].sum())
# Out:
# 12.816745011440002
# 11.79010143968

# %%
pd.concat([group.head(1) for _, group in df.sort_values(['Timestamp'], ascending=True).groupby('Character Name')])
# Out:
#               Timestamp Character Name  Level Class Type        BA Party  \
# 0   10/24/2023 11:29:17              a    250        DPS  2.500000
# 1   10/24/2023 11:29:41              b    245        DPS  2.700000
# 2   10/24/2023 11:30:11              c    260        DPS  1.800000
# 3   10/24/2023 11:30:34              d    255        DPS  1.700000
# 4   10/24/2023 11:30:50              e    253        DPS  2.200000
# 6   10/24/2023 11:29:17              g    250        DPS  3.407284
# 7   10/24/2023 11:29:41              h    245        DPS  2.627418
# 8   10/24/2023 11:30:11              i    260        DPS  1.460165
# 9   10/24/2023 11:30:34              j    255        DPS  1.813683
# 10  10/24/2023 11:30:50              k    253        DPS  2.362146
# 11  10/24/2023 11:31:13              l    245    Support  1.435424
#
#     level_diff  fd_multiplier  adjusted_BA
# 0            0           1.10     2.750000
# 1           -5           0.88     2.376000
# ...

# %%
df.loc[df.groupby('Character Name')['Timestamp'].idxmin()]
# Out:
#              Timestamp Character Name  Level Class Type        BA Party  \
# 0  2023-10-24 11:29:17              a    250        DPS  2.500000
# 1  2023-10-24 11:29:41              b    245        DPS  2.700000
# 2  2023-10-24 11:30:11              c    260        DPS  1.800000
# 3  2023-10-24 11:30:34              d    255        DPS  1.700000
# 4  2023-10-24 11:30:50              e    253        DPS  2.200000
# 6  2023-10-24 11:29:17              g    250        DPS  3.407284
# 7  2023-10-24 11:29:41              h    245        DPS  2.627418
# 8  2023-10-24 11:30:11              i    260        DPS  1.460165
# 9  2023-10-24 11:30:34              j    255        DPS  1.813683
# 10 2023-10-24 11:30:50              k    253        DPS  2.362146
# 11 2023-10-24 11:31:13              l    245    Support  1.435424
#
#     level_diff  fd_multiplier  adjusted_BA
# 0            0           1.10     2.750000
# 1           -5           0.88     2.376000
# ...

# %%
df
# Out:
#              Timestamp Character Name  Level Class Type        BA Party  \
# 0  2023-10-24 11:29:17              a    250        DPS  2.500000
# 1  2023-10-24 11:29:41              b    245        DPS  2.700000
# 2  2023-10-24 11:30:11              c    260        DPS  1.800000
# 3  2023-10-24 11:30:34              d    255        DPS  1.700000
# 4  2023-10-24 11:30:50              e    253        DPS  2.200000
# 5  2023-10-24 11:31:13              a    245    Support  1.500000
# 6  2023-10-24 11:29:17              g    250        DPS  3.407284
# 7  2023-10-24 11:29:41              h    245        DPS  2.627418
# 8  2023-10-24 11:30:11              i    260        DPS  1.460165
# 9  2023-10-24 11:30:34              j    255        DPS  1.813683
# 10 2023-10-24 11:30:50              k    253        DPS  2.362146
# 11 2023-10-24 11:31:13              l    245    Support  1.435424
#
#     level_diff  fd_multiplier  adjusted_BA
# 0            0           1.10     2.750000
# ...
